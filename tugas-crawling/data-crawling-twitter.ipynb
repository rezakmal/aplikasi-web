# %% [markdown]
# ## File Ini Di Run Di Collab

# %%
# Twitter Auth Token

twitter_auth_token = '67751269319448547a19a0f4721c74ea95b2954f' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# v20.3.1

# %%
# Crawl Data

filename = 'wasit_bahrain.csv'
search_keyword = 'wasit bahrain since:2024-10-09 until:2024-10-12 lang:id'
limit = 100

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# npm ERR! code ENOENT
# npm ERR! syscall lstat
# npm ERR! path C:\Users\rezaa\AppData\Roaming\npm
# npm ERR! errno -4058
# npm ERR! enoent ENOENT: no such file or directory, lstat 'C:\Users\rezaa\AppData\Roaming\npm'
# npm ERR! enoent This is related to npm not being able to find a file.
# npm ERR! enoent
#
# npm ERR! A complete log of this run can be found in: C:\Users\rezaa\AppData\Local\npm-cache\_logs\2024-10-12T14_58_44_432Z-debug-0.log

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 file_path = f"tweets-data/{filename}"
#       6 # Read the CSV file into a pandas DataFrame
# ----> 7 df = pd.read_csv(file_path, delimiter=",")
#       9 # Display the DataFrame
#      10 display(df)
#
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
